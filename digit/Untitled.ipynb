# %% [markdown]
# # 資料載入

# %%
import pandas as pd
import os

os.environ['CUDA_VISIBLE_DEVICES'] = ""
row_train = pd.read_csv('data/train.csv')
row_test = pd.read_csv('data/test.csv')

label = row_train['label']
row_train = row_train.drop(columns=['label'])

# %% [markdown]
# # 建模

# %%
import keras
import numpy as np
from sklearn.model_selection import train_test_split
from keras import layers

# normalized
train_x = row_train/255
test_x = row_test/255
label_vec = pd.get_dummies(label)

train_x_array = train_x.values.reshape(train_x.shape[0],28,28,1)
test_x_array = test_x.values.reshape(test_x.shape[0],28,28,1)
print(train_x_array.shape)
print(test_x_array.shape)

# 分割資料
train_x, val_x, train_y, val_y = train_test_split(train_x_array,label_vec)

layer_list = [layers.Conv2D(50,kernel_size=(5,5),input_shape=(28,28,1),activation='relu'),
              layers.Conv2D(50,kernel_size=(3,3),activation='relu'),
              layers.MaxPool2D(2,2),
              layers.Conv2D(100,kernel_size=(3,3),activation='relu'),
              layers.MaxPool2D(2,2),
              layers.Conv2D(200,kernel_size=(3,3),activation='relu'),
              layers.MaxPool2D(2,2),
              layers.Flatten(),
              layers.Dense(200,activation='relu'),
              layers.Dense(10,activation='softmax')]

model = keras.models.Sequential(layer_list)
model.compile(loss='categorical_crossentropy',
             optimizer=keras.optimizers.Adam(),
             metrics=['accuracy'])

model.summary()
training_process = model.fit(train_x,train_y,
                             epochs=50,
                             batch_size=100,
                             validation_data=(val_x,val_y))
# Out:
# (42000, 28, 28, 1)
# (28000, 28, 28, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 24, 24, 50)        1300
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 22, 22, 50)        22550
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 11, 11, 50)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 9, 9, 100)         45100
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 4, 4, 100)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 2, 2, 200)         180200
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 1, 1, 200)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2010
# =================================================================
# Total params: 291,360
# Trainable params: 291,360
# Non-trainable params: 0
# _________________________________________________________________
# Train on 31500 samples, validate on 10500 samples
# Epoch 1/50
# 31500/31500 [==============================] - 5s 171us/step - loss: 0.2982 - acc: 0.9072 - val_loss: 0.0776 - val_acc: 0.9768
# Epoch 2/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0686 - acc: 0.9784 - val_loss: 0.0803 - val_acc: 0.9770
# Epoch 3/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0447 - acc: 0.9857 - val_loss: 0.0531 - val_acc: 0.9840
# Epoch 4/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0338 - acc: 0.9893 - val_loss: 0.0465 - val_acc: 0.9858
# Epoch 5/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0281 - acc: 0.9909 - val_loss: 0.0526 - val_acc: 0.9850
# Epoch 6/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0176 - acc: 0.9948 - val_loss: 0.0483 - val_acc: 0.9882
# Epoch 7/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0166 - acc: 0.9947 - val_loss: 0.0495 - val_acc: 0.9890
# Epoch 8/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0147 - acc: 0.9955 - val_loss: 0.0587 - val_acc: 0.9867
# Epoch 9/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0146 - acc: 0.9951 - val_loss: 0.0733 - val_acc: 0.9821
# Epoch 10/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0142 - acc: 0.9957 - val_loss: 0.0507 - val_acc: 0.9890
# Epoch 11/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0100 - acc: 0.9970 - val_loss: 0.0437 - val_acc: 0.9903
# Epoch 12/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0100 - acc: 0.9965 - val_loss: 0.0493 - val_acc: 0.9895
# Epoch 13/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0088 - acc: 0.9970 - val_loss: 0.0468 - val_acc: 0.9916
# Epoch 14/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0095 - acc: 0.9968 - val_loss: 0.0512 - val_acc: 0.9891
# Epoch 15/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0080 - acc: 0.9976 - val_loss: 0.0501 - val_acc: 0.9905
# Epoch 16/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0073 - acc: 0.9978 - val_loss: 0.0603 - val_acc: 0.9852
# Epoch 17/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0083 - acc: 0.9975 - val_loss: 0.0490 - val_acc: 0.9901
# Epoch 18/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0069 - acc: 0.9978 - val_loss: 0.0490 - val_acc: 0.9898
# Epoch 19/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0071 - acc: 0.9981 - val_loss: 0.0658 - val_acc: 0.9875
# Epoch 20/50
# 31500/31500 [==============================] - 5s 149us/step - loss: 0.0071 - acc: 0.9979 - val_loss: 0.0696 - val_acc: 0.9857
# Epoch 21/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0044 - acc: 0.9990 - val_loss: 0.0659 - val_acc: 0.9870
# Epoch 22/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0701 - val_acc: 0.9878
# Epoch 23/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0094 - acc: 0.9973 - val_loss: 0.0755 - val_acc: 0.9870
# Epoch 24/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0054 - acc: 0.9984 - val_loss: 0.0520 - val_acc: 0.9901
# Epoch 25/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0044 - acc: 0.9988 - val_loss: 0.0583 - val_acc: 0.9890
# Epoch 26/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0043 - acc: 0.9991 - val_loss: 0.0768 - val_acc: 0.9861
# Epoch 27/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0078 - acc: 0.9977 - val_loss: 0.0617 - val_acc: 0.9898
# Epoch 28/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0067 - acc: 0.9980 - val_loss: 0.0615 - val_acc: 0.9893
# Epoch 29/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0066 - acc: 0.9982 - val_loss: 0.0616 - val_acc: 0.9884
# Epoch 30/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0031 - acc: 0.9992 - val_loss: 0.0547 - val_acc: 0.9915
# Epoch 31/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0664 - val_acc: 0.9868
# Epoch 32/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 0.0064 - acc: 0.9982 - val_loss: 0.0566 - val_acc: 0.9906
# Epoch 33/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 0.0051 - acc: 0.9985 - val_loss: 0.0526 - val_acc: 0.9910
# Epoch 34/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 8.0275e-04 - acc: 0.9999 - val_loss: 0.0489 - val_acc: 0.9928
# Epoch 35/50
# 31500/31500 [==============================] - 5s 152us/step - loss: 5.3025e-04 - acc: 1.0000 - val_loss: 0.0501 - val_acc: 0.9926
# Epoch 36/50
# 31500/31500 [==============================] - 5s 157us/step - loss: 5.2069e-04 - acc: 1.0000 - val_loss: 0.0505 - val_acc: 0.9928
# Epoch 37/50
# 31500/31500 [==============================] - 5s 151us/step - loss: 5.1774e-04 - acc: 1.0000 - val_loss: 0.0510 - val_acc: 0.9928
# Epoch 38/50
# 31500/31500 [==============================] - 5s 150us/step - loss: 5.1638e-04 - acc: 1.0000 - val_loss: 0.0515 - val_acc: 0.9927
# Epoch 39/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 5.1544e-04 - acc: 1.0000 - val_loss: 0.0520 - val_acc: 0.9927
# Epoch 40/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 5.1474e-04 - acc: 1.0000 - val_loss: 0.0525 - val_acc: 0.9927
# Epoch 41/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 5.1419e-04 - acc: 1.0000 - val_loss: 0.0530 - val_acc: 0.9927
# Epoch 42/50
# 31500/31500 [==============================] - 5s 149us/step - loss: 5.1376e-04 - acc: 1.0000 - val_loss: 0.0535 - val_acc: 0.9927
# Epoch 43/50
# 31500/31500 [==============================] - 5s 151us/step - loss: 5.1342e-04 - acc: 1.0000 - val_loss: 0.0540 - val_acc: 0.9927
# Epoch 44/50
# 31500/31500 [==============================] - 5s 148us/step - loss: 5.1314e-04 - acc: 1.0000 - val_loss: 0.0545 - val_acc: 0.9928
# Epoch 45/50
# 31500/31500 [==============================] - 5s 149us/step - loss: 5.1292e-04 - acc: 1.0000 - val_loss: 0.0549 - val_acc: 0.9928
# Epoch 46/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 5.1273e-04 - acc: 1.0000 - val_loss: 0.0554 - val_acc: 0.9928
# Epoch 47/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 5.1258e-04 - acc: 1.0000 - val_loss: 0.0559 - val_acc: 0.9928
# Epoch 48/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 5.1245e-04 - acc: 1.0000 - val_loss: 0.0563 - val_acc: 0.9927
# Epoch 49/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 5.1235e-04 - acc: 1.0000 - val_loss: 0.0567 - val_acc: 0.9926
# Epoch 50/50
# 31500/31500 [==============================] - 5s 147us/step - loss: 5.1226e-04 - acc: 1.0000 - val_loss: 0.0571 - val_acc: 0.9926

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,16))
plt.plot(training_process.history['acc'])
plt.plot(training_process.history['val_acc'])
plt.xlabel('epochs')
plt.ylabel('acc')
plt.title('Accuracy')
plt.show()

# %%
pred = np.argmax(model.predict(test_x_array), axis=1)

index = pd.DataFrame(range(1,test_x.shape[0]+1),columns=['ImageId'])
pred = pd.DataFrame(pred,columns=['Label'])

res_df = pd.concat([index,pred],axis=1)
res_df.to_csv('res.csv',index=False)
